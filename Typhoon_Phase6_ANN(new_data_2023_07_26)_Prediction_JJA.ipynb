# %% [markdown]
# <a href="https://colab.research.google.com/github/tigerjk726/Bumjoong/blob/main/Typhoon_Phase6_ANN(new_data_2023_07_26)_Prediction_JJA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.metrics import mean_squared_error, accuracy_score
from sklearn.model_selection import LeaveOneOut
from sklearn.model_selection import cross_val_predict
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from statistics import mean
from sklearn.ensemble import RandomForestRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import LeaveOneOut, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
import statsmodels.api as sm
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
cv = LeaveOneOut()
import os
import pandas as pd
import datetime
from google.colab import drive
import os
import pandas as pd
import pickle
import numpy as np

drive.mount('/content/drive')

# %cd /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal

# %%
filelist = ['ACCESS-ESM1-5_piControl.txt',
 'ACCESS-ESM1-5_1pctCO2.txt',
 'ACCESS-ESM1-5_1pctCO2-cdr.txt',
 'CESM2_piControl.txt',
 'CESM2_1pctCO2.txt',
 'CESM2_1pctCO2-cdr.txt',
 'CNRM-ESM2-1_piControl.txt',
 'CNRM-ESM2-1_1pctCO2.txt',
 'CNRM-ESM2-1_1pctCO2-cdr.txt',
 'CanESM5_piControl.txt',
 'CanESM5_1pctCO2.txt',
 'CanESM5_1pctCO2-cdr.txt',
 'GFDL-ESM4_piControl.txt',
 'GFDL-ESM4_1pctCO2.txt',
 'GFDL-ESM4_1pctCO2-cdr.txt',
 'MIROC-ES2L_piControl.txt',
 'MIROC-ES2L_1pctCO2.txt',
 'MIROC-ES2L_1pctCO2-cdr.txt',
 'UKESM1-0-LL_NIMS_piControl.txt',
 'UKESM1-0-LL_NIMS_D-1pctCO2-cdr_r1.txt',
 'UKESM1-0-LL_NIMS_D-1pctCO2-cdr_r2.txt',
 'UKESM1-0-LL_NIMS_D-1pctCO2-cdr_r3.txt',
 'UKESM1-0-LL_NIMS_D-2pctCO2-cdr_r1.txt',
 'UKESM1-0-LL_NIMS_D-2pctCO2-cdr_r2.txt',
 'UKESM1-0-LL_NIMS_D-2pctCO2-cdr_r3.txt',
 'UKESM1-0-LL_NIMS_A-1pctCO2-cdr_r1.txt',
 'UKESM1-0-LL_NIMS_A-1pctCO2-cdr_r2.txt',
 'UKESM1-0-LL_NIMS_A-1pctCO2-cdr_r3.txt',
 'UKESM1-0-LL_NIMS_A-2pctCO2-cdr_r1.txt',
 'UKESM1-0-LL_NIMS_A-2pctCO2-cdr_r2.txt',
 'UKESM1-0-LL_NIMS_A-2pctCO2-cdr_r3.txt',
 'UKESM1-0-LL_NIMS_B-1pctCO2-cdr_r1.txt',
 'UKESM1-0-LL_NIMS_B-1pctCO2-cdr_r2.txt',
 'UKESM1-0-LL_NIMS_B-1pctCO2-cdr_r3.txt',
 'UKESM1-0-LL_NIMS_B-2pctCO2-cdr_r1.txt',
 'UKESM1-0-LL_NIMS_B-2pctCO2-cdr_r2.txt',
 'UKESM1-0-LL_NIMS_B-2pctCO2-cdr_r3.txt',
 'UKESM1-0-LL_NIMS_C-1pctCO2-cdr_r1.txt',
 'UKESM1-0-LL_NIMS_C-1pctCO2-cdr_r2.txt',
 'UKESM1-0-LL_NIMS_C-1pctCO2-cdr_r3.txt',
 'UKESM1-0-LL_NIMS_C-2pctCO2-cdr_r1.txt',
 'UKESM1-0-LL_NIMS_C-2pctCO2-cdr_r2.txt',
 'UKESM1-0-LL_NIMS_C-2pctCO2-cdr_r3.txt']

# %%
import tensorflow as tf

# Loop through all the subdirectories
# %cd /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal/


for x in filelist:

  directory = "monthly"

  df_list = []

  for subdir in os.listdir(directory):
      subdir_path = os.path.join(directory, subdir)
      if os.path.isdir(subdir_path):
          for foldername in os.listdir(subdir_path):
              if foldername == 'CMIP6_cdr':
                  filepath = os.path.join(subdir_path, foldername)
                  # Loop through all CSV files in the directory
                  for filename in os.listdir(filepath):
                      if filename.endswith(x):
                          filepath = os.path.join(filepath, filename)
                          with open(filepath) as f:
                              lines = [line.split() for line in f]
                          data = []
                          for line in lines:
                              year = int(line[0])
                              values = [float(y) for y in line[1:]]
                              row_dict = {'year': year}
                              for i, value in enumerate(values):
                                  month = i + 1
                                  month_name = pd.Timestamp(year=2000, month=month, day=1).strftime('%B').lower()
                                  month_name = datetime.datetime.strptime(month_name, "%B").month
                                  row_dict[month_name] = value
                              data.append(row_dict)
                        # create the DataFrame
                          df = pd.DataFrame(data)
                          df = df.melt(id_vars=['year'], var_name='month', value_name=filename.replace('.txt', ''))
                          df = df.sort_values(['year', 'month'])
                          column_name = filename.replace('.txt', '')
                          # df[column_name] = scaler.fit_transform(df[column_name].values.reshape(-1, 1))
                          df_list.append(df)

  # Concatenate all DataFrames in the list into a single DataFrame
  rawdata_df = pd.concat(df_list, ignore_index=True)
  rawdata_df = rawdata_df[rawdata_df['month'].isin([7, 8, 9])]
  rawdata_df.drop('month', axis=1, inplace=True)
    # Group by year and month and aggregate values
  rawdata_df = rawdata_df.groupby(['year']).mean().reset_index()

  # Define the country codes dictionary
  country_codes = {
      'australia': 0,
      'bangla': 1,
      'caribbean': 2,
      'china': 3,
      'india': 4,
      'japan': 5,
      'korea': 6,
      'madagascar': 7,
      'mexic2': 8,
      'mexico': 9,
      'myanmar': 10,
      'phili': 11,
      'pakistan': 12,
      'sri': 13,
      'taiwan': 14,
      'us2': 15,
      'us': 16,
      'vietnam': 17,
  }

  result_dfs = []

  # Loop through each key-value pair in the country codes dictionary
  for key, value in country_codes.items():
      # Make a copy of the rawdata_df for each country
      country_df = rawdata_df.copy()

      # Set the country and name columns in the country_df
      country_df['country'] = value
      country_df['name'] = key

      # Append the country_df to the result_dfs list
      result_dfs.append(country_df)

  # Concatenate all dataframes in the result_dfs list into a single dataframe
  alldfs = pd.concat(result_dfs, ignore_index=True)

  # one-hot encoding using pandas.get_dummies() method
  one_hot = pd.get_dummies(alldfs['country'])

  # concatenate the one-hot encoded dataframe with the original dataframe
  alldfs = pd.concat([alldfs, one_hot], axis=1)

  name_col = alldfs.pop('name')
  country_col = alldfs.pop('country')
  alldfs.insert(len(alldfs.columns), 'name', name_col)
  alldfs.insert(len(alldfs.columns), 'country', country_col)


  # Set the directory path
  # %cd /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal

  with open('model_freq_20230725_JJA.pkl', 'rb') as f:
    model_N_loaded = pickle.load(f)


  # alldfs = alldfs[~alldfs['country'].isin([0,1,2,4,7,8,9,10,12,13,15,17])].reset_index(drop=True)
  included_countries = [3, 5, 6, 11, 14, 16]

  # Set the directory path to "result"
  result_directory = "JJA/result"
  os.makedirs(result_directory, exist_ok=True)

  for y in included_countries:
    alldfs_filtered = alldfs[alldfs['country'].isin([y])].reset_index(drop=True)
    country_names = {value: key for key, value in country_codes.items()}
    y_country_name = country_names.get(y)

    # Split the data into training and test sets
    alldfs_x1_train = alldfs_filtered.iloc[:, 1:30]
    alldfs_x1_test = alldfs_filtered.iloc[:, 1:30]
    alldfs_y1_train = alldfs_filtered.iloc[:, [0, 30]]
    alldfs_y1_test = alldfs_filtered.iloc[:, [0, 30]]

    # Predict the output for the test set
    y1_pred = model_N_loaded.predict(alldfs_x1_test)

    # Convert predictions to DataFrame and concatenate with country and month columns
    y1_pred_df = pd.DataFrame({"year": alldfs_y1_test.iloc[:, 0].values, "country": alldfs_y1_test.iloc[:, 1].values, "Freq_pred": np.squeeze(y1_pred)})
    y1_pred_df = y1_pred_df[['year', 'country', 'Freq_pred']]

    # Save predictions to CSV file in the "result" folder
    filepath = os.path.join(result_directory, f'Freq_pred_ANN_Predicfor_{y_country_name}_{x}.csv')
    y1_pred_df.to_csv(filepath, index=False)

  # %cd /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal/
# Out:
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 5/5 [==============================] - 0s 3ms/step
# 5/5 [==============================] - 0s 3ms/step
# 5/5 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 24/24 [==============================] - 0s 1ms/step
# 24/24 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 1ms/step
# 24/24 [==============================] - 0s 1ms/step
# 24/24 [==============================] - 0s 1ms/step
# 24/24 [==============================] - 0s 1ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 38/38 [==============================] - 0s 1ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 1ms/step
# 38/38 [==============================] - 0s 1ms/step
# 38/38 [==============================] - 0s 1ms/step
# 38/38 [==============================] - 0s 1ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 5/5 [==============================] - 0s 4ms/step
# 5/5 [==============================] - 0s 3ms/step
# 5/5 [==============================] - 0s 4ms/step
# 5/5 [==============================] - 0s 3ms/step
# 5/5 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 7/7 [==============================] - 0s 3ms/step
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 3ms/step
# 7/7 [==============================] - 0s 3ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 5/5 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 3ms/step
# 5/5 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 3ms/step
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 33/33 [==============================] - 0s 2ms/step
# 33/33 [==============================] - 0s 1ms/step
# 33/33 [==============================] - 0s 1ms/step
# 33/33 [==============================] - 0s 1ms/step
# 33/33 [==============================] - 0s 1ms/step
# 33/33 [==============================] - 0s 1ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 5/5 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 5/5 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 3ms/step
# 5/5 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 3ms/step
# 5/5 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 3ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 7/7 [==============================] - 0s 4ms/step
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 3ms/step
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 1ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 5/5 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 3ms/step
# 5/5 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 3ms/step
# 5/5 [==============================] - 0s 3ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 3ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 59/59 [==============================] - 0s 1ms/step
# 59/59 [==============================] - 0s 1ms/step
# 59/59 [==============================] - 0s 1ms/step
# 59/59 [==============================] - 0s 1ms/step
# 59/59 [==============================] - 0s 1ms/step
# 59/59 [==============================] - 0s 1ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 15/15 [==============================] - 0s 1ms/step
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 1ms/step
# 15/15 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 15/15 [==============================] - 0s 1ms/step
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 1ms/step
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 15/15 [==============================] - 0s 3ms/step
# 15/15 [==============================] - 0s 3ms/step
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 11/11 [==============================] - 0s 3ms/step
# 11/11 [==============================] - 0s 4ms/step
# 11/11 [==============================] - 0s 3ms/step
# 11/11 [==============================] - 0s 3ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 5ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 3ms/step
# 11/11 [==============================] - 0s 3ms/step
# 11/11 [==============================] - 0s 3ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# <ipython-input-20-b61886da1fbb>:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdata_df.drop('month', axis=1, inplace=True)
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 3ms/step
# 11/11 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 3ms/step
# 11/11 [==============================] - 0s 3ms/step
# 11/11 [==============================] - 0s 3ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 3ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 3ms/step
# 11/11 [==============================] - 0s 3ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal

# %%
# %cd /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal/

scaler = StandardScaler()

for x in filelist:

  directory = "monthly"

  df_list = []

  for subdir in os.listdir(directory):
      subdir_path = os.path.join(directory, subdir)
      if os.path.isdir(subdir_path):
          for foldername in os.listdir(subdir_path):
              if foldername == 'CMIP6_cdr':
                  filepath = os.path.join(subdir_path, foldername)
                  # Loop through all CSV files in the directory
                  for filename in os.listdir(filepath):
                      if filename.endswith(x):
                          filepath = os.path.join(filepath, filename)
                          with open(filepath) as f:
                              lines = [line.split() for line in f]
                          data = []
                          for line in lines:
                              year = int(line[0])
                              values = [float(y) for y in line[1:]]
                              row_dict = {'year': year}
                              for i, value in enumerate(values):
                                  month = i + 1
                                  month_name = pd.Timestamp(year=2000, month=month, day=1).strftime('%B').lower()
                                  month_name = datetime.datetime.strptime(month_name, "%B").month
                                  row_dict[month_name] = value
                              data.append(row_dict)
                        # create the DataFrame
                          df = pd.DataFrame(data)
                          df = df.melt(id_vars=['year'], var_name='month', value_name=filename.replace('.txt', ''))
                          df = df.sort_values(['year', 'month'])
                          column_name = filename.replace('.txt', '')
                          # df[column_name] = scaler.fit_transform(df[column_name].values.reshape(-1, 1))
                          df_list.append(df)



  # Concatenate all DataFrames in the list into a single DataFrame
  rawdata_df = pd.concat(df_list, ignore_index=True)
  rawdata_df = rawdata_df[rawdata_df['month'].isin([7, 8, 9])]
  #rawdata_df = rawdata_df.groupby('year')[7, 8, 9].mean().reset_index()
  rawdata_df.drop('month', axis=1, inplace=True)

  # Group by year and month and aggregate values
  rawdata_df = rawdata_df.groupby(['year']).mean().reset_index()

  # Define the country codes dictionary
  country_codes = {
      'australia': 0,
      'bangla': 1,
      'caribbean': 2,
      'china': 3,
      'india': 4,
      'japan': 5,
      'korea': 6,
      'madagascar': 7,
      'mexic2': 8,
      'mexico': 9,
      'myanmar': 10,
      'phili': 11,
      'pakistan': 12,
      'sri': 13,
      'taiwan': 14,
      'us2': 15,
      'us': 16,
      'vietnam': 17,
  }

  result_dfs = []

  # Loop through each key-value pair in the country codes dictionary
  for key, value in country_codes.items():
      # Make a copy of the rawdata_df for each country
      country_df = rawdata_df.copy()

      # Set the country and name columns in the country_df
      country_df['country'] = value
      country_df['name'] = key

      # Append the country_df to the result_dfs list
      result_dfs.append(country_df)

  # Concatenate all dataframes in the result_dfs list into a single dataframe
  alldfs = pd.concat(result_dfs, ignore_index=True)

  # one-hot encoding using pandas.get_dummies() method
  one_hot = pd.get_dummies(alldfs['country'])

  # concatenate the one-hot encoded dataframe with the original dataframe
  alldfs = pd.concat([alldfs, one_hot], axis=1)

  name_col = alldfs.pop('name')
  country_col = alldfs.pop('country')
  alldfs.insert(len(alldfs.columns), 'name', name_col)
  alldfs.insert(len(alldfs.columns), 'country', country_col)

  # Set the directory path
  # %cd /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal/

  # Load the model from the pickle file in the model folder
  with open('model_inten_20230725_JJA.pkl', 'rb') as f:
      model_N_loaded = pickle.load(f)

  # alldfs = alldfs[~alldfs['country'].isin([0,1,2,4,7,8,9,10,12,13,15,17])].reset_index(drop=True)
  included_countries = [3, 5, 6, 11, 14, 16]
  # Set the directory path to "result"
  result_directory = "JJA/result"
  os.makedirs(result_directory, exist_ok=True)

  for y in included_countries:
    alldfs_filtered = alldfs[alldfs['country'].isin([y])].reset_index(drop=True)
    country_names = {value: key for key, value in country_codes.items()}
    y_country_name = country_names.get(y)

    # Split the data into training and test sets
    alldfs_x2_train = alldfs_filtered.iloc[:, 1:30]
    alldfs_x2_test = alldfs_filtered.iloc[:, 1:30]
    alldfs_y2_train = alldfs_filtered.iloc[:, [0, 30]]
    alldfs_y2_test = alldfs_filtered.iloc[:, [0, 30]]

    # Predict the output for the test set
    y2_pred = model_N_loaded.predict(alldfs_x2_test)

    # Convert predictions to DataFrame and concatenate with country and month columns
    y2_pred_df = pd.DataFrame({"year":  alldfs_y2_test.iloc[:, 0].values, "country": alldfs_y2_test.iloc[:, 1].values, "Inten_pred": np.squeeze(y2_pred)})
    y2_pred_df = y2_pred_df[['year', 'country', 'Inten_pred']]

    # Save predictions to CSV file in the "result" folder
    filepath = os.path.join(result_directory, f'Inten_pred_ANN_Predicfor_{y_country_name}_{x}.csv')
    y2_pred_df.to_csv(filepath, index=False)


  # %cd /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal/
# Out:
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 5/5 [==============================] - 0s 3ms/step
# 5/5 [==============================] - 0s 4ms/step
# 5/5 [==============================] - 0s 4ms/step
# 5/5 [==============================] - 0s 4ms/step
# 5/5 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 3ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 24/24 [==============================] - 0s 1ms/step
# 24/24 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 1ms/step
# 24/24 [==============================] - 0s 1ms/step
# 24/24 [==============================] - 0s 1ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 1ms/step
# 38/38 [==============================] - 0s 1ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 1ms/step
# 38/38 [==============================] - 0s 1ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 5/5 [==============================] - 0s 3ms/step
# 5/5 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 3ms/step
# 5/5 [==============================] - 0s 3ms/step
# 5/5 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 3ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 7/7 [==============================] - 0s 4ms/step
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 3ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 5/5 [==============================] - 0s 3ms/step
# 5/5 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 3ms/step
# 5/5 [==============================] - 0s 4ms/step
# 5/5 [==============================] - 0s 4ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 3ms/step
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 33/33 [==============================] - 0s 1ms/step
# 33/33 [==============================] - 0s 1ms/step
# 33/33 [==============================] - 0s 1ms/step
# 33/33 [==============================] - 0s 1ms/step
# 33/33 [==============================] - 0s 1ms/step
# 33/33 [==============================] - 0s 1ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 5/5 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 4ms/step
# 5/5 [==============================] - 0s 3ms/step
# 5/5 [==============================] - 0s 3ms/step
# 5/5 [==============================] - 0s 3ms/step
# 5/5 [==============================] - 0s 3ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 5/5 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 5ms/step
# 5/5 [==============================] - 0s 4ms/step
# 5/5 [==============================] - 0s 4ms/step
# 5/5 [==============================] - 0s 4ms/step
# 5/5 [==============================] - 0s 3ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 5ms/step
# 7/7 [==============================] - 0s 5ms/step
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 5/5 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 4ms/step
# 5/5 [==============================] - 0s 3ms/step
# 5/5 [==============================] - 0s 3ms/step
# 5/5 [==============================] - 0s 4ms/step
# 5/5 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 1ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 59/59 [==============================] - 0s 1ms/step
# 59/59 [==============================] - 0s 1ms/step
# 59/59 [==============================] - 0s 2ms/step
# 59/59 [==============================] - 0s 1ms/step
# 59/59 [==============================] - 0s 1ms/step
# 59/59 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 1ms/step
# 15/15 [==============================] - 0s 1ms/step
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 1ms/step
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 1ms/step
# 15/15 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 3ms/step
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 3ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 3ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 11/11 [==============================] - 0s 3ms/step
# 11/11 [==============================] - 0s 3ms/step
# 11/11 [==============================] - 0s 3ms/step
# 11/11 [==============================] - 0s 3ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 3ms/step
# 11/11 [==============================] - 0s 3ms/step
# 11/11 [==============================] - 0s 3ms/step
# 11/11 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 4ms/step
# 11/11 [==============================] - 0s 4ms/step
# 11/11 [==============================] - 0s 6ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 11/11 [==============================] - 0s 3ms/step
# 11/11 [==============================] - 0s 3ms/step
# 11/11 [==============================] - 0s 3ms/step
# 11/11 [==============================] - 0s 3ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 3ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 11/11 [==============================] - 0s 3ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 3ms/step
# 11/11 [==============================] - 0s 3ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# <ipython-input-22-0e9d95d210c9>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdata_df.drop('month', axis=1, inplace=True)
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 4ms/step
# 11/11 [==============================] - 0s 3ms/step
# 11/11 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 3ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 3ms/step
# 11/11 [==============================] - 0s 3ms/step
# 11/11 [==============================] - 0s 2ms/step
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal

# %%
# Load the predictions from the CSV file
y1_pred_df = pd.read_csv('y_pred_ANN_freq_20230725_JJA.csv')

# Plot the predictions and actual values for y1 by country and month
countries = y1_pred_df['country'].unique()

for country in countries:
    country_pred_df = y1_pred_df[y1_pred_df['country'] == country]
    country_pred_df = country_pred_df.groupby('year').agg({'y1_actual': 'sum', 'y1_pred': 'sum'}).reset_index()
    rmse_1 = np.sqrt(mean_squared_error(country_pred_df['y1_actual'], country_pred_df['y1_pred']))
    print("RMSE for y1:", rmse_1)
    corr = country_pred_df['y1_actual'].corr(country_pred_df['y1_pred'])
    print("Correlation for y1:", corr)
    plt.figure(figsize=(30, 6))
    plt.plot(country_pred_df['year'], country_pred_df['y1_pred'], label="Predicted", linewidth=2, linestyle='-', marker='s', markersize=5, alpha=0.7)
    plt.plot(country_pred_df['year'], country_pred_df['y1_actual'], label="Actual", linewidth=2, linestyle='--', marker='o', markersize=5, alpha=1)
    plt.title(f"Predicted vs Actual Values for Frequency in {country}")
    plt.legend()
    plt.show()
# Out:
# RMSE for y1: 0.8341438976195746
# Correlation for y1: 0.9195915909523146
# RMSE for y1: 0.9047176013567976
# Correlation for y1: 0.8768532319115999
# RMSE for y1: 0.6445209041841928
# Correlation for y1: 0.8838238655340953
# RMSE for y1: 0.980056049773518
# Correlation for y1: 0.8420856157690684
# RMSE for y1: 0.8078153979294063
# Correlation for y1: 0.8218517392476522
# RMSE for y1: 0.9393464210686017
# Correlation for y1: 0.7991774698551671

# %%
# %cd /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal/JJA/result

# Load the predictions from the CSV file
y_pred_df = pd.read_csv('Freq_pred_ANN_Predicfor_china_ACCESS-ESM1-5_piControl.txt.csv')
# Plot the predictions and actual values for Inten by country and month
countries = y_pred_df['country'].unique()

mean
for country in countries:
    country_pred_df = y_pred_df[y_pred_df['country'] == country]
    country_pred_df['Freq_pred'] = country_pred_df['Freq_pred'].apply(lambda x: max(0, x))
    plt.figure(figsize=(30, 6))
    plt.plot(country_pred_df['year'], country_pred_df['Freq_pred'], label="Predicted", linewidth=2, linestyle='-', marker='s', markersize=5, alpha=0.7)
    plt.legend()
    plt.show()
# Out:
# /content/drive/My Drive/8.Colab Notebooks/2023.0723 Seasonal/JJA/result
